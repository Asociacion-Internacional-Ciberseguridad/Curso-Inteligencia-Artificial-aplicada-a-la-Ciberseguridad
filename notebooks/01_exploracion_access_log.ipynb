# %% [markdown]
# # Exploración de access.log
#
# Notebook para cargar el CSV generado desde `access.log` y revisar eventos web.

# %%
import pandas as pd

df = pd.read_csv("access.csv")
df.head()

# %%
df["tipo_ataque"].value_counts()

# %%
df["ip_origen"].value_counts().head(10)
