# %% [markdown]
# # Limpieza de datos
#
# Ejemplo de revisión de nulos, tipos de datos y columnas.

# %%
import pandas as pd

access = pd.read_csv("processed/access.csv")
access.info()

# %%
access.isna().sum()
