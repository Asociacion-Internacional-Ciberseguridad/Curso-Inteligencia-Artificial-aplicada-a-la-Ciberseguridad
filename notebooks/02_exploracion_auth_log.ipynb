# %% [markdown]
# # Exploración de auth.log
#
# Análisis de eventos SSH y autenticación Linux.

# %%
import pandas as pd

df = pd.read_csv("auth.csv")
df.head()

# %%
df["evento"].value_counts()

# %%
df[df["es_ataque"] == 1]["ip_origen"].value_counts().head(10)
