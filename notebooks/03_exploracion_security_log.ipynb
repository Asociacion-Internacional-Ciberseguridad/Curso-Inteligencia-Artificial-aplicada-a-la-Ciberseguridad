# %% [markdown]
# # Exploración de Windows Security Log
#
# Revisión de Event ID, usuarios e IPs origen.

# %%
import pandas as pd

df = pd.read_csv("security.csv")
df.head()

# %%
df["event_id"].value_counts()

# %%
df[df["es_sospechoso"] == 1]["source_ip"].value_counts()
